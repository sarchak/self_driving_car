# %% [markdown]
# # Self-Driving Car Engineer Nanodegree
#
# ## Deep Learning
#
# ## Project: Build a Traffic Sign Recognition Classifier
#
# In this notebook, a template is provided for you to implement your functionality in stages which is required to successfully complete this project. If additional code is required that cannot be included in the notebook, be sure that the Python code is successfully imported and included in your submission, if necessary. Sections that begin with **'Implementation'** in the header indicate where you should begin your implementation for your project. Note that some sections of implementation are optional, and will be marked with **'Optional'** in the header.
#
# In addition to implementing code, there will be questions that you must answer which relate to the project and your implementation. Each section where you will answer a question is preceded by a **'Question'** header. Carefully read each question and provide thorough answers in the following text boxes that begin with **'Answer:'**. Your project submission will be evaluated based on your answers to each of the questions and the implementation you provide.
#
# >**Note:** Code and Markdown cells can be executed using the **Shift + Enter** keyboard shortcut. In addition, Markdown cells can be edited by typically double-clicking the cell to enter edit mode.

# %% [markdown]
# ---
# ## Step 0: Load The Data

# %%
import tensorflow as tf
from tensorflow.contrib.layers import flatten
from matplotlib import gridspec
from sklearn.utils import shuffle
from datetime import datetime
import numpy as np
import pandas as pd
import cv2
import pickle
### Data exploration visualization goes here.
### Feel free to use as many code cells as needed.
import matplotlib.pyplot as plt
import matplotlib
matplotlib.style.use('ggplot')


# Visualizations will be shown in the notebook.
# %matplotlib inline

# %%
# Load pickled data
import pickle
# TODO: Fill this in based on where you saved the training and testing data

training_file = './train.p'
testing_file = './test.p'

with open(training_file, mode='rb') as f:
    train = pickle.load(f)
with open(testing_file, mode='rb') as f:
    test = pickle.load(f)
    
X_train, y_train = train['features'], train['labels']
X_test, y_test = test['features'], test['labels']

# %% [markdown]
# ### Distribution before augmenting

# %%
plt.hist(y_train, bins=len(np.unique(y_train)))
plt.show()

# %% [markdown]
# ### Step 1: Dataset Summary & Exploration
#
# The pickled data is a dictionary with 4 key/value pairs:
#    * 'features' is a 4D array containing raw pixel data of the traffic sign images, (num examples, width, height, channels).
#    * 'labels' is a 2D array containing the label/class id of the traffic sign. The file signnames.csv contains id -> name mappings for each id.
#    * 'sizes' is a list containing tuples, (width, height) representing the the original width and height the image.
#    * 'coords' is a list containing tuples, (x1, y1, x2, y2) representing coordinates of a bounding box around the sign in the image. ***THESE COORDINATES ASSUME THE ORIGINAL IMAGE. THE PICKLED DATA CONTAINS RESIZED VERSIONS (32 by 32) OF THESE IMAGES***
# Complete the basic data summary below.

# %%
# Load pickled data
import pickle    
X_train_exploration, y_train_exploration = train['features'], train['labels']
X_test_exploration, y_test_exploration = test['features'], test['labels']
print("**** Features ***** ")
#print(train['features'])
print(train['features'].shape)
print("**** Labels ***** ")
#print(train['labels'])
print(train['labels'].shape)
print("**** Sizes ***** ")
#print(train['sizes'])
print(train['sizes'].shape)
print("**** Coords ***** ")
#print(train['coords'])
print(train['coords'].shape)
# Out:
# **** Features *****
# (39209, 32, 32, 3)
# **** Labels *****
# (39209,)
# **** Sizes *****
# (39209, 2)
# **** Coords *****
# (39209, 4)

# %% [markdown]
# Visualize the German Traffic Signs Dataset using the pickled file(s). This is open ended, suggestions include: plotting traffic sign images, plotting the count of each sign, etc.
#
# The [Matplotlib](http://matplotlib.org/) [examples](http://matplotlib.org/examples/index.html) and [gallery](http://matplotlib.org/gallery.html) pages are a great resource for doing visualizations in Python.
#
# **NOTE:** It's recommended you start with something simple first. If you wish to do more, come back to it after you've completed the rest of the sections.

# %%
### Data exploration visualization goes here.
### Feel free to use as many code cells as needed.
import matplotlib.pyplot as plt
# Visualizations will be shown in the notebook.
# %matplotlib inline

# %%
import itertools
def rgb2gray(rgb):
    return np.dot(rgb[...,:3], [0.299, 0.587, 0.114])

def transform_image(img,ang_range,shear_range,trans_range):
    '''
    This function transforms images to generate new images.
    The function takes in following arguments,
    1- Image
    2- ang_range: Range of angles for rotation
    3- shear_range: Range of values to apply affine transform to
    4- trans_range: Range of values to apply translations over.

    A Random uniform distribution is used to generate different parameters for transformation

    '''
    # Rotation
    t1 = datetime.now()

    ang_rot = np.random.uniform(ang_range)-ang_range/2
    rows,cols,ch = img.shape
    Rot_M = cv2.getRotationMatrix2D((cols/2,rows/2),ang_rot,1)

    # Translation
    tr_x = trans_range*np.random.uniform()-trans_range/2
    tr_y = trans_range*np.random.uniform()-trans_range/2
    Trans_M = np.float32([[1,0,tr_x],[0,1,tr_y]])

    # Shear
    pts1 = np.float32([[5,5],[20,5],[5,20]])

    pt1 = 5+shear_range*np.random.uniform()-shear_range/2
    pt2 = 20+shear_range*np.random.uniform()-shear_range/2

    pts2 = np.float32([[pt1,5],[pt2,pt1],[5,pt2]])

    shear_M = cv2.getAffineTransform(pts1,pts2)

    img = cv2.warpAffine(img,Rot_M,(cols,rows))
    img = cv2.warpAffine(img,Trans_M,(cols,rows))
    img = cv2.warpAffine(img,shear_M,(cols,rows))

    # Denoise
    #img = cv2.fastNlMeansDenoisingColored(img,None,10,10,7,21)
    t2 = datetime.now()


    return img

def augment_for_class(X, label, target_length):
    tmp_x = []
    for t in X:
        tmp_x.append(t)
    length = X.shape[0]
    tmp_y = [label] * length
    for i in range(0,target_length):
        img = tmp_x[np.random.randint(0, length)]
        angle = np.random.randint(0, 22)
        shear = np.random.randint(0, 12)
        transform = np.random.randint(0, 10)
        img = transform_image(img, 20,10,5)
        tmp_x.append(img)
        tmp_y.append(label)
    return(tmp_x, tmp_y)

def augmented_data_new(X, y):
  x_shape = X.shape
  y_shape = y.shape
  X_train_augmented = []
  y_train_augmented = []
  uniq_class = len(np.unique(y))
  idx = 0
  fin_size = 0
  print("************* Starting Augmenting data *****************")
  for class_type in range(0,uniq_class):
    t = np.where(y == class_type)
    idx = t[0]
    tmp_x,tmp_y = augment_for_class(X[idx], class_type, 1000)
    X_train_augmented.append(tmp_x)
    y_train_augmented.append(tmp_y)

  X_train_augmented = list(itertools.chain(*X_train_augmented))
  y_train_augmented = list(itertools.chain(*y_train_augmented))
  fin_size = len(X_train_augmented)
  X_train_augmented = np.array(X_train_augmented, dtype=np.float32).reshape([fin_size, 32, 32, 3])
  y_train_augmented = np.array(y_train_augmented, dtype=np.int32).reshape(fin_size,)
  return(X_train_augmented, y_train_augmented)


def augmented_data(X, y, samples=3):
  x_shape = X.shape
  y_shape = y.shape
  X_train_augmented = []
  y_train_augmented = []
  idx = 0
  print("************* Starting Augmenting data")
  for (img, label) in zip(X_train, y_train):
    idx += 1
    tmp_x = [img]
    tmp_y = [label]
    for i in range(0,samples):
        img = transform_image(img, 20,10,5)
        tmp_x.append(img)
        tmp_y.append(label)
    X_train_augmented.append(tmp_x)
    y_train_augmented.append(tmp_y)

  X_train_augmented = np.array(X_train_augmented,dtype = np.float32()).reshape([len(X_train)*(samples+1), 32, 32, 3])
  y_train_augmented = np.array(y_train_augmented,dtype = np.int32()).reshape(len(y_train)*(samples+1),)
  return(X_train_augmented, y_train_augmented)

# %%
new_style = {'grid': False}
matplotlib.rc('axes', **new_style)

sample = np.arange(0,len(X_train_exploration))
np.random.shuffle(sample)
sample = sample[0:10]
#plt.figure(figsize=(6,8))
gs1 = gridspec.GridSpec(2, 5)
for i in range(0,10):
    ax1 = plt.subplot(gs1[i])
    plt.subplot(2,5,i+1)
    img = X_train_exploration[sample[i]]
    plt.imshow(img)
plt.show()

X_train_exploration = rgb2gray(X_train_exploration).reshape(-1, 32, 32, 1)
X_train_exploration = X_train_exploration/255

# X_train_exploration = center_normalize(X_train_exploration, mean, std)
gs2 = gridspec.GridSpec(2, 5)
for i in range(0,10):
    ax1 = plt.subplot(gs2[i])
    plt.subplot(2,5,i+1)
    img = X_train_exploration[sample[i]]
    plt.imshow(img.reshape(32,32), cmap='gray')
plt.show()

# %% [markdown]
# ----
#
# ## Step 2: Design and Test a Model Architecture
#
# Design and implement a deep learning model that learns to recognize traffic signs. Train and test your model on the [German Traffic Sign Dataset](http://benchmark.ini.rub.de/?section=gtsrb&subsection=dataset).
#
# There are various aspects to consider when thinking about this problem:
#
# - Neural network architecture
# - Play around preprocessing techniques (normalization, rgb to grayscale, etc)
# - Number of examples per label (some have more than others).
# - Generate fake data.
#
# Here is an example of a [published baseline model on this problem](http://yann.lecun.com/exdb/publis/pdf/sermanet-ijcnn-11.pdf). It's not required to be familiar with the approach used in the paper but, it's good practice to try to read papers like these.
#
# **NOTE:** The LeNet-5 implementation shown in the [classroom](https://classroom.udacity.com/nanodegrees/nd013/parts/fbf77062-5703-404e-b60c-95b78b2f3f9e/modules/6df7ae49-c61c-4bb2-a23e-6527e69209ec/lessons/601ae704-1035-4287-8b11-e2c2716217ad/concepts/d4aca031-508f-4e0b-b493-e7b706120f81) at the end of the CNN lesson is a solid starting point. You'll have to change the number of classes and possibly the preprocessing, but aside from that it's plug and play!

# %% [markdown]
# ### Implementation
#
# Use the code cell (or multiple code cells, if necessary) to implement the first step of your project. Once you have completed your implementation and are satisfied with the results, be sure to thoroughly answer the questions that follow.

# %% [markdown]
# ### Question 1
#
# _Describe how you preprocessed the data. Why did you choose that technique?_

# %% [markdown]
# **Answer:**
# I preprocessed the data by normalizing the value between 0 to 1. We can think of traffic sign detection as some form of detecting the edges or the shape with each shape having a specific meaning. By removing the RGB channels we can easily find the difference or gradient in an image which will be a useful feature for the model to learn.
#
# Additionally I one hot encoded the target variable. The target variable will be a 1*43 vector.

# %%
### Generate data additional data (OPTIONAL!)
### and split the data into training/validation/testing sets here.
### Feel free to use as many code cells as needed.

# %%
### Preprocess the data here.
### Feel free to use as many code cells as needed.
#Shuffle train

X_train, y_train = shuffle(X_train, y_train)
X_train, y_train = augmented_data_new(X_train, y_train)
X_train, y_train = shuffle(X_train, y_train)
X_train = rgb2gray(X_train).reshape(-1, 32, 32, 1)
X_test = rgb2gray(X_test).reshape(-1, 32, 32, 1)

X_train = X_train/255
X_test=X_test/255


### Replace each question mark with the appropriate value.

# TODO: Number of training examples
n_train = X_train.shape[0]

# TODO: Number of testing examples.
n_test = X_test.shape[0]

# TODO: What's the shape of an traffic sign image?
image_shape = X_train[0].shape

# TODO: How many unique classes/labels there are in the dataset.
n_classes = len(np.unique(y_train))

print("Number of training examples =", n_train)
print("Number of testing examples =", n_test)
print("Image data shape =", image_shape)
print("Number of classes =", n_classes)
# Out:
# ************* Starting Augmenting data *****************
# Number of training examples = 82209
# Number of testing examples = 12630
# Image data shape = (32, 32, 1)
# Number of classes = 43

# %% [markdown]
# ### Distribution after augmenting the data

# %%
plt.hist(y_train, bins=len(np.unique(y_train)))
plt.show()

# %% [markdown]
# ### Split train data into X_train and X_validation

# %%
validation_size = int(0.10 * n_train)

X_train_1 = X_train[0:-validation_size]
y_train_1 = y_train[0:-validation_size]

X_validation = X_train[-validation_size:]
y_validation = y_train[-validation_size:]
X_train = X_train_1
y_train = y_train_1
print()
print("Image Shape: {}".format(X_train[0].shape))
print()
print("Training Set:   {} samples".format(len(X_train)))
print("Validation Set: {} samples".format(len(X_validation)))
print("Test Set:       {} samples".format(len(X_test)))


print("Updated Image Shape: {}".format(X_train[0].shape))
# Out:
# Image Shape: (32, 32, 1)
#
# Training Set:   73989 samples
# Validation Set: 8220 samples
# Test Set:       12630 samples
# Updated Image Shape: (32, 32, 1)

# %% [markdown]
# ### Question 2
#
# _Describe how you set up the training, validation and testing data for your model. **Optional**: If you generated additional data, how did you generate the data? Why did you generate the data? What are the differences in the new dataset (with generated data) from the original dataset?_

# %% [markdown]
# **Answer:**
# ### Augment Data
# I augmented the data by translating the image, shearing and rotating the images. If our aim is to detect the traffic sign with a video feed coming from a camera mounted on the car. Depending on how far, close it is to the traffic sign the way it looks might differ and we want to be able correctly predict the sign correct. So transforming the data like this will be more realistic.
#
#    * Augment data by changing rotating, shear, translation and denoise the image
#    * Convert RGB to Gray scale
#    * Normalize the RGB values
#    * Tried 2 different approaches augmented_data and augmented_data_new . Augmented_data is as per discussed in the Udacity forums and the slack channels.
#    * I used 10% of the data for validation and remaining 90% for training the data.
#    * Tried 2 different approaches
#       * Adding 3 to 5 new images per image which didn't change the distribution of the data
#       * Creating 3000 images per class. Lets say we have 2000 images of class 1 in training then I only augment 1000 images to the class 1 to bring the total images per class to 3000. Similarly if there were only 500 images of class 2 in training I would add 2500 images which are transformed to bring the total to 3000 images per class.
#       * Finally used this approach add 1000 images per class.

# %%
### Define your architecture here.
### Feel free to use as many code cells as needed.

# %%
### Convnet helper functions
def weight_variable(shape, name):
  initial = tf.truncated_normal(shape, stddev=0.01)
  return tf.Variable(initial, name=name)

def bias_variable(shape, name):
  initial = tf.constant(0.01, shape=shape)
  return tf.Variable(initial, name=name)


def conv2d(x, W):
  return tf.nn.conv2d(x, W, strides=[1, 1, 1, 1], padding='SAME')

def max_pool_2x2(x):
  return tf.nn.max_pool(x, ksize=[1, 2, 2, 1],
                        strides=[1, 2, 2, 1], padding='SAME')

layer_depth = {
    'layer_1': 48,
    'layer_2': 64,
    'layer_3': 128,
    'fc1': 512,
    'fc2': 512,
    'out': 43
}

weights = {
    'layer_1': weight_variable([3, 3, 1, layer_depth['layer_1']], 'weights_1'),
    'layer_2': weight_variable([3, 3, layer_depth['layer_1'], layer_depth['layer_2']], 'weights_2'),
    'layer_3': weight_variable([3, 3, layer_depth['layer_2'], layer_depth['layer_3']], 'weights_3'),
    'fc1': weight_variable([4*4*128, layer_depth['fc1']], 'weights_fc1'),
    'fc2': weight_variable([layer_depth['fc1'], layer_depth['fc2']], 'weights_fc2'),
    'out': weight_variable([layer_depth['fc2'], 43],'weights_out')
}
biases = {
    'layer_1': bias_variable([layer_depth['layer_1']], 'bias_1'),
    'layer_2': bias_variable([layer_depth['layer_2']], 'bias_2'),
    'layer_3': bias_variable([layer_depth['layer_3']], 'bias_3'),
    'fc1': bias_variable([layer_depth['fc1']], 'bias_fc1'),
    'fc2': bias_variable([layer_depth['fc2']], 'bias_fc2'),
    'out': bias_variable([layer_depth['out']], 'bias_out'),
}

# weight_layers = {'layer1': 48, 'layer2':64, 'layer3': 128, 'fc1': 512, 'fc2': 512}
# biases_layers = {'layer1': 48, 'layer2':64, 'layer3': 128, 'fc1': 512, 'fc2': 512}

# %%
def conv_net(x, weights, biases, keep_prob):
    W_conv1 = weights['layer_1']
    b_conv1 = biases['layer_1']

    h_conv1 = tf.nn.relu(conv2d(x, W_conv1) + b_conv1)
    h_pool1 = max_pool_2x2(h_conv1)
    #h_pool1_drop = tf.nn.dropout(h_pool1, keep_prob)

    W_conv2 = weights['layer_2']
    b_conv2 = biases['layer_2']

    h_conv2 = tf.nn.relu(conv2d(h_pool1, W_conv2) + b_conv2)
    h_pool2 = max_pool_2x2(h_conv2)
    h_pool2_drop = tf.nn.dropout(h_pool2, keep_prob)

    W_conv3 = weights['layer_3']
    b_conv3 = biases['layer_3']

    h_conv3 = tf.nn.relu(conv2d(h_pool2_drop, W_conv3) + b_conv3)
    h_pool3 = max_pool_2x2(h_conv3)
    h_pool3_drop = tf.nn.dropout(h_pool3, keep_prob)

    W_fc1 = weights['fc1']
    b_fc1 = biases['fc1']

    h_pool3_flat = tf.reshape(h_pool3_drop, [-1, 4 * 4 * layer_depth['layer_3']])
    h_fc1 = tf.nn.relu(tf.matmul(h_pool3_flat, W_fc1) + b_fc1)

    h_fc1_drop = tf.nn.dropout(h_fc1, keep_prob)

    W_fc2 = weights['fc2']
    b_fc2 = biases['fc2']

    fc2 = tf.matmul(h_fc1_drop, W_fc2) + b_fc2
    h_fc2_drop = tf.nn.dropout(fc2, keep_prob)

    W_fc3 = weights['out']
    b_fc3 = biases['out']

    out = tf.matmul(h_fc2_drop, W_fc3) + b_fc3
    return out

# %% [markdown]
# ### Question 3
#
# _What does your final architecture look like? (Type of model, layers, sizes, connectivity, etc.)  For reference on how to build a deep neural network using TensorFlow, see [Deep Neural Network in TensorFlow
# ](https://classroom.udacity.com/nanodegrees/nd013/parts/fbf77062-5703-404e-b60c-95b78b2f3f9e/modules/6df7ae49-c61c-4bb2-a23e-6527e69209ec/lessons/b516a270-8600-4f93-a0a3-20dfeabe5da6/concepts/83a3a2a2-a9bd-4b7b-95b0-eb924ab14432) from the classroom._

# %% [markdown]
# **Answer:**
#
# Here is the final architecture:
#    * Input layer with [32, 32, 1]
#    * Conv layer with 3 by 3 filter, stride 1, SAME padding, input depth 1 with output depth of 48 ( aka feature maps)
#    * RELU
#    * Maxpool 2x2 ( With 2 by 2 kernel size and stride of 2)
#    * Conv2 layer with 3 by 3 filter, stride 1, SAME padding input depth 48 and output depth of 64
#    * RELU
#    * Maxpool 2x2 ( With 2 by 2 kernel size and stride of 2)
#    * Dropout layer (Keep_prob : 0.75)
#    * Conv3 layer with 3 by 3 filter, stride 1, SAME padding input depth 64 and output depth of 128
#    * Maxpool 2x2 ( With 2 by 2 kernel size and stride of 2)
#    * Dropout layer (Keep_prob : 0.75)
#    * FC1 with 512 node
#    * RELU
#    * Dropout layer (Keep_prob : 0.75)
#    * FC2 with 512 node
#    * RELU
#    * Dropout layer (Keep_prob : 0.75)
#    * Op layer with 43 nodes

# %% [markdown]
# ![Neural Network](nn.png)

# %%
### Train your model here.
### Feel free to use as many code cells as needed.

# %%
EPOCHS = 40
BATCH_SIZE = 256
save_file = 'review_v2'

x = tf.placeholder(tf.float32, (None, 32, 32, 1))
y = tf.placeholder(tf.int32, (None))
keep_prob = tf.placeholder(tf.float32)

one_hot_y = tf.one_hot(y, 43)
rate = 0.001

logits = conv_net(x, weights, biases, keep_prob)
cross_entropy = tf.nn.softmax_cross_entropy_with_logits(logits, one_hot_y)
loss_operation = tf.reduce_mean(cross_entropy)
optimizer = tf.train.AdamOptimizer(learning_rate = rate)
training_operation = optimizer.minimize(loss_operation)
correct_prediction = tf.equal(tf.argmax(logits, 1), tf.argmax(one_hot_y, 1))
accuracy_operation = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

sess = tf.Session()
sess.run(tf.global_variables_initializer())

def evaluate(X_data, y_data):
    num_examples = len(X_data)
    total_accuracy = 0
    #sess = tf.get_default_session()
    for offset in range(0, num_examples, BATCH_SIZE):
        batch_x, batch_y = X_data[offset:offset+BATCH_SIZE], y_data[offset:offset+BATCH_SIZE]
        accuracy = sess.run(accuracy_operation, feed_dict={x: batch_x, y: batch_y, keep_prob: 1.0})
        total_accuracy += (accuracy * len(batch_x))
    return total_accuracy / num_examples

num_examples = len(X_train)

print("Training...")
print()
vacc = []
trainacc = []
ldata = []
for i in range(EPOCHS):
    X_train, y_train = shuffle(X_train, y_train)
    for offset in range(0, num_examples, BATCH_SIZE):
        end = offset + BATCH_SIZE
        batch_x, batch_y = X_train[offset:end], y_train[offset:end]
        l, _ = sess.run([loss_operation, training_operation], feed_dict={x: batch_x, y: batch_y, keep_prob: 0.7})
        ldata.append(l)

    validation_accuracy = evaluate(X_validation, y_validation)
    vacc.append(validation_accuracy)
    training_accuracy = evaluate(X_train, y_train)
    trainacc.append(training_accuracy)
    print("EPOCH {} ...".format(i+1))
    print("Validation Accuracy = {:.3f}".format(validation_accuracy))
    print()

try:
    saver
except NameError:
    saver = tf.train.Saver()
saver.save(sess, save_file)
print("Model saved")
test_accuracy = evaluate(X_test, y_test)
print("Test Accuracy = {:.3f}".format(test_accuracy))
# Out:
# Training...
#
# EPOCH 1 ...
# Validation Accuracy = 0.142
#
# EPOCH 2 ...
# Validation Accuracy = 0.579
#
# EPOCH 3 ...
# Validation Accuracy = 0.781
#
# EPOCH 4 ...
# Validation Accuracy = 0.841
#
# EPOCH 5 ...
# Validation Accuracy = 0.870
#
# EPOCH 6 ...
# Validation Accuracy = 0.914
#
# EPOCH 7 ...
# Validation Accuracy = 0.916
#
# EPOCH 8 ...
# Validation Accuracy = 0.936
#
# EPOCH 9 ...
# Validation Accuracy = 0.940
#
# EPOCH 10 ...
# Validation Accuracy = 0.950
#
# EPOCH 11 ...
# Validation Accuracy = 0.954
#
# EPOCH 12 ...
# Validation Accuracy = 0.962
#
# EPOCH 13 ...
# Validation Accuracy = 0.968
#
# EPOCH 14 ...
# Validation Accuracy = 0.964
#
# EPOCH 15 ...
# Validation Accuracy = 0.971
#
# EPOCH 16 ...
# Validation Accuracy = 0.971
#
# EPOCH 17 ...
# Validation Accuracy = 0.972
#
# EPOCH 18 ...
# Validation Accuracy = 0.975
#
# EPOCH 19 ...
# Validation Accuracy = 0.976
#
# EPOCH 20 ...
# Validation Accuracy = 0.977
#
# EPOCH 21 ...
# Validation Accuracy = 0.977
#
# EPOCH 22 ...
# Validation Accuracy = 0.976
#
# EPOCH 23 ...
# Validation Accuracy = 0.979
#
# EPOCH 24 ...
# Validation Accuracy = 0.980
#
# EPOCH 25 ...
# Validation Accuracy = 0.978
#
# EPOCH 26 ...
# Validation Accuracy = 0.980
#
# EPOCH 27 ...
# Validation Accuracy = 0.983
#
# EPOCH 28 ...
# Validation Accuracy = 0.977
#
# EPOCH 29 ...
# Validation Accuracy = 0.980
#
# EPOCH 30 ...
# Validation Accuracy = 0.981
#
# EPOCH 31 ...
# Validation Accuracy = 0.985
#
# EPOCH 32 ...
# Validation Accuracy = 0.983
#
# EPOCH 33 ...
# Validation Accuracy = 0.982
#
# EPOCH 34 ...
# Validation Accuracy = 0.983
#
# EPOCH 35 ...
# Validation Accuracy = 0.983
#
# EPOCH 36 ...
# Validation Accuracy = 0.984
#
# EPOCH 37 ...
# Validation Accuracy = 0.984
#
# EPOCH 38 ...
# Validation Accuracy = 0.986
#
# EPOCH 39 ...
# Validation Accuracy = 0.985
#
# EPOCH 40 ...
# Validation Accuracy = 0.983
#
# Model saved
# Test Accuracy = 0.970

# %%
### With 40 Epochs
df = pd.DataFrame(data={'train_accuracy': trainacc, 'validation_accuracy': vacc})
df.plot()

# %%
### With 40 Epochs
df = pd.DataFrame(data={'loss': ldata[0:10000]})
df.plot()

# %% [markdown]
# ### Question 4
#
# _How did you train your model? (Type of optimizer, batch size, epochs, hyperparameters, etc.)_

# %% [markdown]
# **Answer:**
#
#    * Started with SGD classifier and tried different with 1, 0.1, 0.5 and 0.01.
#    * SGD tends to converge slowly so moved to adam optimizer.
#    * Get baseline number without data augmentation.
#    * Tried different learning rate and finally settled with 0.001
#    * Tried different values for batch size : 32, 64, 128 and 256
#    * Change filter size 5*5, 3*3
#    * Epoch
#       * Lower epochs when no dropout was used
#       * High epochs when dropout was added
#
# Plotted the training accuracy and validation accuracy. The plot show where the training accuracy is not improving beyond and becoming flat.

# %% [markdown]
# ### Question 5
#
#
# _What approach did you take in coming up with a solution to this problem? It may have been a process of trial and error, in which case, outline the steps you took to get to the final solution and why you chose those steps. Perhaps your solution involved an already well known implementation or architecture. In this case, discuss why you think this is suitable for the current problem._

# %% [markdown]
# **Answer:**
#
# #### Run 1
#    * Started with the Lenet and the architecture defined in the course with no preprocessing or augmenting the data
#    * Accuracy was low
#
# #### Run 2
#    * With the above architecture just normalized the train and test images
#    * Set the standard deviation to 0.1 for bias and weights
#    * Good train and validation accuracy with around 92% test accuracy
#    * Tried different layers from 1 to 4
#
# #### Run 3 to Run N
#    * Created a hybrid architecture with with 3,3 patch size and stride of 2
#    * 48, 64 and 128 feature maps for the conv1, conv2 and conv3 layers
#       * Started with a small architecture 8, 16, 32 for the conv layer and capturing test accuracy at each iteration
#       * Training was slow on cpu moved to aws gpu's at this point
#       * Finally settled on these values
#    * Max pooling after each conv
#    * 2 FC layers at the end
#
# #### Run Final
#    * With the above architecture training and validation accuracy was good but was overfitting the data
#    * Started adding dropout layers
#
# I used the above architecture as it gave me better results.

# %% [markdown]
# ---
#
# ## Step 3: Test a Model on New Images
#
# Take several pictures of traffic signs that you find on the web or around you (at least five), and run them through your classifier on your computer to produce example results. The classifier might not recognize some local signs but it could prove interesting nonetheless.
#
# You may find `signnames.csv` useful as it contains mappings from the class id (integer) to the actual sign name.

# %% [markdown]
# ### Implementation
#
# Use the code cell (or multiple code cells, if necessary) to implement the first step of your project. Once you have completed your implementation and are satisfied with the results, be sure to thoroughly answer the questions that
# follow.

# %%
### Helper method for id to SignName
import csv
with open('signnames.csv') as f:
    sign_dict = dict(filter(None, csv.reader(f)))

def signName(id):
    return sign_dict[str(id)]

# %% [markdown]
# ### Using the Belgium Traffic Sign Dataset to validate our model

# %%
### Load the images and plot them here.
### Feel free to use as many code cells as needed.

from scipy.misc import imread
test_images = []

for i in range(0,30):
    image = imread("belgium_traffic_sign/test"+str(i)+".png")
    image = image.astype(np.uint8)
    test_images.append(image)
test_data = np.array(test_images)

test_data = rgb2gray(test_data).reshape(-1, 32, 32, 1)
test_data = test_data / 255

# %%
def print_probs(probs, labels, img):    
    plt.figure(figsize=(4, 3))
    plt.subplot(222)
    plt.imshow(img)
    performance = probs.tolist()
    performance.reverse()
    labels.reverse()
    labels = labels
    plt.subplot(221)
    y_pos = np.arange(len(performance))
    plt.barh(y_pos, performance, align='center', alpha=0.5, height=0.2)
    plt.yticks(y_pos, labels)
    plt.title('Predicted Probabilities')
    plt.show()

# %% [markdown]
# ### Question 6
#
# _Choose five candidate images of traffic signs and provide them in the report. Are there any particular qualities of the image(s) that might make classification difficult? It could be helpful to plot the images in the notebook._

# %% [markdown]
# **Answer:**
#    * In some cases like the right only it is not able to differentiate right only and no entry. Since no entry sign is almost similar to right only expect the edge with arrow. I think if we had not converted to gray scale probably it would be able to identify it as right only and not no entry by the background color of the traffic sign.
#    * Similarly for signs like both road narrows ahead it was not able to identify it and classify it as general caution. Where as the model was able to classify right road narrows ahead correctly.
#    * Basically the model is getting confused when it has 2 different signs merged together.

# %%
### Run the predictions here.
### Feel free to use as many code cells as needed.

# %%
new_style = {'grid': False}
matplotlib.rc('axes', **new_style)

res = sess.run(logits, feed_dict={x: test_data, keep_prob: 1.0})
predicts = sess.run(tf.nn.top_k(res, k=5, sorted=True))
plt.figure(figsize=(15, 15))
gs3 = gridspec.GridSpec(6, 5)
for i in range(0,30):
    ax1 = plt.subplot(gs3[i])
    plt.subplot(6,5,i+1)
    probs = sess.run(tf.nn.softmax(predicts[0][i]))
    plt.imshow(test_images[i])
    plt.text(0,1,str(signName(predicts[1][i][0])),color='k',backgroundcolor='y')
    
    
plt.subplots_adjust(wspace=0.5, hspace=0.5)
plt.show()
# image_show = 30
# fig, ax = plt.subplots(1,image_show,figsize=(16,2))
# for k in range(0, image_show):
#     ax[k].imshow(test_images[test_ids[k]])
#     ax[k].set_title(str(signName(predicts[1][i][0])))

# %% [markdown]
# ### Question 7
#
#
# _Is your model able to perform equally well on captured pictures when compared to testing on the dataset? The simplest way to do this check the accuracy of the predictions. For example, if the model predicted 1 out of 5 signs correctly, it's 20% accurate._
#
# _**NOTE:** You could check the accuracy manually by using `signnames.csv` (same directory). This file has a mapping from the class id (0-42) to the corresponding sign name. So, you could take the class id the model outputs, lookup the name in `signnames.csv` and see if it matches the sign from the image._

# %% [markdown]
# **Answer:**
# The model was able to get around 97% on test images where as the on the dataset from the internet it was able to get 66.6% accuracy. Some of the images which I picked were not in the training dataset.

# %%
### Visualize the softmax probabilities here.
### Feel free to use as many code cells as needed.

# %%
plt.figure(figsize=(5, 5))
res = sess.run(logits, feed_dict={x: test_data, keep_prob: 1.0})
data = sess.run(tf.nn.softmax(res[1]))
plt.plot(data,marker='o')

# %%
plt.figure(figsize=(5, 5))
res = sess.run(logits, feed_dict={x: test_data, keep_prob: 1.0})
data = sess.run(tf.nn.softmax(res[5]))
plt.plot(data,marker='o')

# %% [markdown]
# ### Question 8
#
# *Use the model's softmax probabilities to visualize the **certainty** of its predictions, [`tf.nn.top_k`](https://www.tensorflow.org/versions/r0.12/api_docs/python/nn.html#top_k) could prove helpful here. Which predictions is the model certain of? Uncertain? If the model was incorrect in its initial prediction, does the correct prediction appear in the top k? (k should be 5 at most)*
#
# `tf.nn.top_k` will return the values and indices (class ids) of the top k predictions. So if k=3, for each sign, it'll return the 3 largest probabilities (out of a possible 43) and the correspoding class ids.
#
# Take this numpy array as an example:
#
# ```
# # (5, 6) array
# a = np.array([[ 0.24879643,  0.07032244,  0.12641572,  0.34763842,  0.07893497,
#          0.12789202],
#        [ 0.28086119,  0.27569815,  0.08594638,  0.0178669 ,  0.18063401,
#          0.15899337],
#        [ 0.26076848,  0.23664738,  0.08020603,  0.07001922,  0.1134371 ,
#          0.23892179],
#        [ 0.11943333,  0.29198961,  0.02605103,  0.26234032,  0.1351348 ,
#          0.16505091],
#        [ 0.09561176,  0.34396535,  0.0643941 ,  0.16240774,  0.24206137,
#          0.09155967]])
# ```
#
# Running it through `sess.run(tf.nn.top_k(tf.constant(a), k=3))` produces:
#
# ```
# TopKV2(values=array([[ 0.34763842,  0.24879643,  0.12789202],
#        [ 0.28086119,  0.27569815,  0.18063401],
#        [ 0.26076848,  0.23892179,  0.23664738],
#        [ 0.29198961,  0.26234032,  0.16505091],
#        [ 0.34396535,  0.24206137,  0.16240774]]), indices=array([[3, 0, 5],
#        [0, 1, 4],
#        [0, 5, 1],
#        [1, 3, 5],
#        [1, 4, 3]], dtype=int32))
# ```
#
# Looking just at the first row we get `[ 0.34763842,  0.24879643,  0.12789202]`, you can confirm these are the 3 largest probabilities in `a`. You'll also notice `[3, 0, 5]` are the corresponding indices.

# %% [markdown]
# **Answer:**
#
# For correct predictions:
# From the data it looks like for correct prediction the model was very certain about the classification with a high softmax probability
#
# Model is uncertain when it hasn't either seen the data before or when there are more than one traffic signed combined.
#
# ### Results
#    * 1) True Result : Yield
#       * Model was 100% certain about that ( Predicted correct)
#    * 2) True Result : Left Turn,
#       * Model was 5% sure about it being left( Predicted incorrect, but the correct was within top 5)
#    * 3) True Result : No Passing
#       * Model was 100% certain about that ( Predicted correct)
#    * 4) True Result : Railway Crossing
#       * This was not in the training dataset but model predicted it was some sort of crossing
#    * 5) True Result : Bumpy Road
#       * Model was 100% certain about that ( Predicted correct)
#    * 6) True Result : No parking
#       * This was not in the training dataset and model din't predict it correctly
#    * 7) True Result : 50 Kmph
#       * Model was 98% certain about the correct result ( Predicted correct)
#    * 8) True Result : Stay Right
#       * Model didn't predict it correctly neither was it in the top 5
#    * 9) True REsult  : Part of the road reserver for cycle
#       * Was not in training data and didn't predict it correctly
#    * 10) True Result : Road narrows on the right
#       * Model predicted correctly with 100% accuracy (Predicted correct)
#    * 11) True Result : Ahead only
#       * Model was 98% certain about the correct result ( Predicted correct)
#    * 12) True Result : Dangerous curve to the left
#       * Model was 99% certain about the correct result ( Predicted correct)
#    * 13) True Result : Speed limit 70kmph
#       * Model was 30% certain about the correct result. Correct result was in the top 5
#    * 14) True Result : Right of way at the next intersection
#       * Model was 100% certain about that ( Predicted correct)
#    * 15) True Result : No vehicles
#       * Model was 100% certain about that ( Predicted correct)
#    * 16) True Result : Children crossing
#       * Model was 3% certain about the correct result. Correct result was in the top 5
#    * 17) True Result : Double Curve
#       * Model was 99.9% certain about the correct result ( Predicted correct)
#    * 18) True Result : No entry for cycles
#       * Incorrect prediction
#    * 19) True Result : Wild animal crossing
#       * 0.2 certain about the correct result but was in top 5
#    * 20) True Result : Roadwork
#    * 21) True Result : Traffic Sign
#    * 22) True Result : General Caution
#       * (20, 21 and 22 model was 99% certain about the correct result. Correct predictions)
#    * 23) True REsult :Road narrows
#       * Model predicted as 58% certain about narrow on the right.
#    * 24) True REsult : Go Straight or right
#    * 25) True Result: Round about
#    * 26) True Result: No entry
#    * 27) True Result: Stop
#    * 28) True Result: No vehicle about 3.5 tonne
#    * 29) True Result: Priority Road
#    * 30) True Result: Bump road
#       * (24-30) Model predicted with high confidence about being correct. Predicted correct

# %%
res = sess.run(logits, feed_dict={x: test_data, keep_prob: 1.0})
predicts = sess.run(tf.nn.top_k(res, k=5, sorted=True))

for i in range(0,30):    
    plt.figure(figsize=(1,1))
    probs = sess.run(tf.nn.softmax(predicts[0][i]))
    for k in range(0,5):
        print("Class : %s , Certainty prob: %f" % (signName(predicts[1][i][k]), probs[k]*100))
    labels = [signName(predicts[1][i][0]), signName(predicts[1][i][1]), signName(predicts[1][i][2]), signName(predicts[1][i][3]), signName(predicts[1][i][4])]
    print_probs(probs, labels, test_images[i])
    print("------------------")
# Out:
# Class : Yield , Certainty prob: 100.000000
# Class : End of all speed and passing limits , Certainty prob: 0.000000
# Class : Keep left , Certainty prob: 0.000000
# Class : Right-of-way at the next intersection , Certainty prob: 0.000000
# Class : Bumpy road , Certainty prob: 0.000000
# ------------------
# Class : Roundabout mandatory , Certainty prob: 85.787696
# Class : No entry , Certainty prob: 8.978199
# Class : Turn left ahead , Certainty prob: 5.175738
# Class : Keep right , Certainty prob: 0.033670
# Class : Vechiles over 3.5 metric tons prohibited , Certainty prob: 0.024694
# ------------------
# Class : No passing , Certainty prob: 100.000000
# Class : Vechiles over 3.5 metric tons prohibited , Certainty prob: 0.000000
# Class : End of all speed and passing limits , Certainty prob: 0.000000
# Class : No passing for vechiles over 3.5 metric tons , Certainty prob: 0.000000
# Class : Slippery road , Certainty prob: 0.000000
# ------------------
# Class : Bumpy road , Certainty prob: 58.699715
# Class : Slippery road , Certainty prob: 40.343070
# Class : Bicycles crossing , Certainty prob: 0.814186
# Class : Wild animals crossing , Certainty prob: 0.142896
# Class : Dangerous curve to the right , Certainty prob: 0.000130
# ------------------
# Class : Bumpy road , Certainty prob: 100.000000
# Class : Traffic signals , Certainty prob: 0.000005
# Class : Bicycles crossing , Certainty prob: 0.000000
# Class : Dangerous curve to the left , Certainty prob: 0.000000
# Class : General caution , Certainty prob: 0.000000
# ------------------
# Class : Speed limit (50km/h) , Certainty prob: 59.154552
# Class : Speed limit (70km/h) , Certainty prob: 37.826863
# Class : Speed limit (120km/h) , Certainty prob: 2.274710
# Class : Stop , Certainty prob: 0.691307
# Class : Speed limit (30km/h) , Certainty prob: 0.052567
# ------------------
# Class : Speed limit (50km/h) , Certainty prob: 98.379946
# Class : Speed limit (80km/h) , Certainty prob: 1.293723
# Class : No passing for vechiles over 3.5 metric tons , Certainty prob: 0.192681
# Class : Speed limit (60km/h) , Certainty prob: 0.130015
# Class : Speed limit (100km/h) , Certainty prob: 0.003643
# ------------------
# Class : No entry , Certainty prob: 100.000000
# Class : Turn left ahead , Certainty prob: 0.000001
# Class : Stop , Certainty prob: 0.000000
# Class : Keep left , Certainty prob: 0.000000
# Class : Keep right , Certainty prob: 0.000000
# ------------------
# Class : Keep right , Certainty prob: 98.916161
# Class : Turn left ahead , Certainty prob: 0.937342
# Class : Roundabout mandatory , Certainty prob: 0.125550
# Class : Go straight or right , Certainty prob: 0.019998
# Class : Ahead only , Certainty prob: 0.000953
# ------------------
# Class : Road narrows on the right , Certainty prob: 100.000000
# Class : Pedestrians , Certainty prob: 0.000001
# Class : General caution , Certainty prob: 0.000000
# Class : Traffic signals , Certainty prob: 0.000000
# Class : Ahead only , Certainty prob: 0.000000
# ------------------
# Class : Ahead only , Certainty prob: 99.999452
# Class : Turn left ahead , Certainty prob: 0.000518
# Class : Turn right ahead , Certainty prob: 0.000022
# Class : Go straight or left , Certainty prob: 0.000002
# Class : No vechiles , Certainty prob: 0.000000
# ------------------
# Class : Dangerous curve to the left , Certainty prob: 99.999952
# Class : Slippery road , Certainty prob: 0.000045
# Class : Traffic signals , Certainty prob: 0.000005
# Class : Bicycles crossing , Certainty prob: 0.000005
# Class : Double curve , Certainty prob: 0.000000
# ------------------
# Class : Speed limit (20km/h) , Certainty prob: 70.275819
# Class : Speed limit (70km/h) , Certainty prob: 27.160797
# Class : Speed limit (30km/h) , Certainty prob: 2.188976
# Class : Speed limit (120km/h) , Certainty prob: 0.321409
# Class : Speed limit (50km/h) , Certainty prob: 0.053007
# ------------------
# Class : Right-of-way at the next intersection , Certainty prob: 100.000000
# Class : Road work , Certainty prob: 0.000000
# Class : Beware of ice/snow , Certainty prob: 0.000000
# Class : Pedestrians , Certainty prob: 0.000000
# Class : Double curve , Certainty prob: 0.000000
# ------------------
# Class : No vechiles , Certainty prob: 100.000000
# Class : Yield , Certainty prob: 0.000000
# Class : Priority road , Certainty prob: 0.000000
# Class : Speed limit (70km/h) , Certainty prob: 0.000000
# Class : Bumpy road , Certainty prob: 0.000000
# ------------------
# Class : Right-of-way at the next intersection , Certainty prob: 90.933579
# Class : Beware of ice/snow , Certainty prob: 5.271731
# Class : Children crossing , Certainty prob: 3.794146
# Class : Dangerous curve to the right , Certainty prob: 0.000522
# Class : Pedestrians , Certainty prob: 0.000037
# ------------------
# Class : Double curve , Certainty prob: 99.963999
# Class : Wild animals crossing , Certainty prob: 0.036004
# Class : Right-of-way at the next intersection , Certainty prob: 0.000002
# Class : Beware of ice/snow , Certainty prob: 0.000001
# Class : Slippery road , Certainty prob: 0.000000
# ------------------
# Class : Right-of-way at the next intersection , Certainty prob: 47.326422
# Class : Beware of ice/snow , Certainty prob: 38.296220
# Class : Children crossing , Certainty prob: 9.805463
# Class : Pedestrians , Certainty prob: 4.529987
# Class : Traffic signals , Certainty prob: 0.041924
# ------------------
# Class : Slippery road , Certainty prob: 96.255976
# Class : Beware of ice/snow , Certainty prob: 3.474012
# Class : Wild animals crossing , Certainty prob: 0.217231
# Class : Double curve , Certainty prob: 0.034938
# Class : Dangerous curve to the right , Certainty prob: 0.017858
# ------------------
# Class : Road work , Certainty prob: 99.990857
# Class : Pedestrians , Certainty prob: 0.004547
# Class : Right-of-way at the next intersection , Certainty prob: 0.003221
# Class : General caution , Certainty prob: 0.001380
# Class : Double curve , Certainty prob: 0.000001
# ------------------
# Class : Traffic signals , Certainty prob: 99.693644
# Class : General caution , Certainty prob: 0.280451
# Class : Pedestrians , Certainty prob: 0.012906
# Class : Bumpy road , Certainty prob: 0.007705
# Class : Road work , Certainty prob: 0.005284
# ------------------
# Class : General caution , Certainty prob: 100.000000
# Class : Traffic signals , Certainty prob: 0.000000
# Class : Pedestrians , Certainty prob: 0.000000
# Class : Road narrows on the right , Certainty prob: 0.000000
# Class : Bumpy road , Certainty prob: 0.000000
# ------------------
# Class : Road narrows on the right , Certainty prob: 58.890277
# Class : Pedestrians , Certainty prob: 40.679133
# Class : General caution , Certainty prob: 0.391872
# Class : Traffic signals , Certainty prob: 0.038720
# Class : Road work , Certainty prob: 0.000000
# ------------------
# Class : Go straight or right , Certainty prob: 99.980861
# Class : Turn left ahead , Certainty prob: 0.008579
# Class : Roundabout mandatory , Certainty prob: 0.008413
# Class : Keep right , Certainty prob: 0.002075
# Class : No entry , Certainty prob: 0.000073
# ------------------
# Class : Roundabout mandatory , Certainty prob: 100.000000
# Class : Turn left ahead , Certainty prob: 0.000001
# Class : Keep right , Certainty prob: 0.000000
# Class : Speed limit (100km/h) , Certainty prob: 0.000000
# Class : Speed limit (50km/h) , Certainty prob: 0.000000
# ------------------
# Class : No entry , Certainty prob: 100.000000
# Class : Speed limit (100km/h) , Certainty prob: 0.000000
# Class : Keep right , Certainty prob: 0.000000
# Class : Turn left ahead , Certainty prob: 0.000000
# Class : Priority road , Certainty prob: 0.000000
# ------------------
# Class : Stop , Certainty prob: 100.000000
# Class : Speed limit (120km/h) , Certainty prob: 0.000000
# Class : No entry , Certainty prob: 0.000000
# Class : Keep right , Certainty prob: 0.000000
# Class : Turn left ahead , Certainty prob: 0.000000
# ------------------
# Class : Vechiles over 3.5 metric tons prohibited , Certainty prob: 99.826103
# Class : No passing , Certainty prob: 0.173903
# Class : End of no passing , Certainty prob: 0.000000
# Class : Slippery road , Certainty prob: 0.000000
# Class : No passing for vechiles over 3.5 metric tons , Certainty prob: 0.000000
# ------------------
# Class : Priority road , Certainty prob: 100.000000
# Class : Keep right , Certainty prob: 0.000000
# Class : Roundabout mandatory , Certainty prob: 0.000000
# Class : No entry , Certainty prob: 0.000000
# Class : Keep left , Certainty prob: 0.000000
# ------------------
# Class : Bumpy road , Certainty prob: 100.000000
# Class : Bicycles crossing , Certainty prob: 0.000000
# Class : Traffic signals , Certainty prob: 0.000000
# Class : Slippery road , Certainty prob: 0.000000
# Class : General caution , Certainty prob: 0.000000
# ------------------

# %% [markdown]
# > **Note**: Once you have completed all of the code implementations and successfully answered each question above, you may finalize your work by exporting the iPython Notebook as an HTML document. You can do this by using the menu above and navigating to  \n",
#     "**File -> Download as -> HTML (.html)**. Include the finished document along with this notebook as your submission.
